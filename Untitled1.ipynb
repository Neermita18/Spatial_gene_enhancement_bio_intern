# %%
pip install scanpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import numpy as np
import pandas as pd
import scanpy as sc
#

# %%
adata= sc.read_csv("mouse_VISp_2018-06-14_samples-columns.csv")

# %%
df
# Out:
#                sample_name  sample_id sample_type      organism   donor sex  \
# 0      F1S4_160108_001_A01  527128530       Cells  Mus musculus  225675   M
# 1      F1S4_160108_001_B01  527128536       Cells  Mus musculus  225675   M
# 2      F1S4_160108_001_C01  527128542       Cells  Mus musculus  225675   M
# 3      F1S4_160108_001_D01  527128548       Cells  Mus musculus  225675   M
# 4      F1S4_160108_001_E01  527128554       Cells  Mus musculus  225675   M
# ...                    ...        ...         ...           ...     ...  ..
# 15408  FYS4_171004_104_D01  645142573       Cells  Mus musculus  350650   M
# 15409  FYS4_171004_104_E01  645142584       Cells  Mus musculus  350650   M
# 15410  FYS4_171004_104_F01  645142613       Cells  Mus musculus  350650   M
# 15411  FYS4_171004_104_G01  645142648       Cells  Mus musculus  350650   M
# 15412  FYS4_171004_104_H01  645142673       Cells  Mus musculus  350650   M
#
# ...

# %%
df.head(5)
# Out:
#            sample_name  sample_id sample_type      organism   donor sex  \
# 0  F1S4_160108_001_A01  527128530       Cells  Mus musculus  225675   M
# 1  F1S4_160108_001_B01  527128536       Cells  Mus musculus  225675   M
# 2  F1S4_160108_001_C01  527128542       Cells  Mus musculus  225675   M
# 3  F1S4_160108_001_D01  527128548       Cells  Mus musculus  225675   M
# 4  F1S4_160108_001_E01  527128554       Cells  Mus musculus  225675   M
#
#    age_days eye_condition                              genotype  \
# 0        53        Normal  Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 1        53        Normal  Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 2        53        Normal  Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 3        53        Normal  Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 4        53        Normal  Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt
#
#        driver_lines  ... genes_detected_cpm_criterion  \
# 0  Slc32a1-IRES-Cre  ...                        10445
# ...

# %%
df.columns
# Out:
# Index(['sample_name', 'sample_id', 'sample_type', 'organism', 'donor', 'sex',
#        'age_days', 'eye_condition', 'genotype', 'driver_lines',
#        'reporter_lines', 'brain_hemisphere', 'brain_region', 'brain_subregion',
#        'injection_label_direction', 'injection_primary', 'injection_secondary',
#        'injection_tract', 'injection_material',
#        'injection_exclusion_criterion', 'facs_date', 'facs_container',
#        'facs_sort_criteria', 'rna_amplification_set', 'library_prep_set',
#        'library_prep_avg_size_bp', 'seq_name', 'seq_tube', 'seq_batch',
#        'total_reads', 'percent_exon_reads', 'percent_intron_reads',
#        'percent_intergenic_reads', 'percent_rrna_reads',
#        'percent_mt_exon_reads', 'percent_reads_unique', 'percent_synth_reads',
#        'percent_ecoli_reads', 'percent_aligned_reads_total', 'complexity_cg',
#        'genes_detected_cpm_criterion', 'genes_detected_fpkm_criterion',
# ...

# %%
genes= pd.read_csv("mouse_VISp_2018-06-14_genes-rows.csv")

# %%
genes.head()
# Out:
#      gene_symbol    gene_id chromosome  gene_entrez_id  \
# 0  0610005C13Rik  500717483          7           71661
# 1  0610006L08Rik  500717917          7           76253
# 2  0610007P14Rik  500730104         12           58520
# 3  0610009B22Rik  500726890         11           66050
# 4  0610009E02Rik  500702775          2       100125929
#
#                     gene_name
# 0  RIKEN cDNA 0610005C13 gene
# 1  RIKEN cDNA 0610006L08 gene
# 2  RIKEN cDNA 0610007P14 gene
# 3  RIKEN cDNA 0610009B22 gene
# 4  RIKEN cDNA 0610009E02 gene

# %%
genes
# Out:
#          gene_symbol    gene_id chromosome  gene_entrez_id  \
# 0      0610005C13Rik  500717483          7           71661
# 1      0610006L08Rik  500717917          7           76253
# 2      0610007P14Rik  500730104         12           58520
# 3      0610009B22Rik  500726890         11           66050
# 4      0610009E02Rik  500702775          2       100125929
# ...              ...        ...        ...             ...
# 45763       n-R5s142  500721654          8       100861496
# 45764       n-R5s143  500721655          8       100861497
# 45765       n-R5s144  500721656          8       100861498
# 45766       n-R5s146  500721658          8       100861500
# 45767       n-R5s149  500721661          8       100861503
#
#                          gene_name
# 0       RIKEN cDNA 0610005C13 gene
# 1       RIKEN cDNA 0610006L08 gene
# 2       RIKEN cDNA 0610007P14 gene
# 3       RIKEN cDNA 0610009B22 gene
# 4       RIKEN cDNA 0610009E02 gene
# ...                            ...
# ...

# %%
pip install mygene
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
import numpy as np
import warnings
import pandas as pd

from scipy import sparse
import pickle
import anndata
import scanpy as sc
sc.settings.verbosity = 2
import mygene
mg = mygene.MyGeneInfo()

# %%
def sparseload(filename):
    genes = []
    sparseblocks = []
    areas = []
    cells = []
    
    # Read the CSV file in chunks
    for chunk in pd.read_csv(filename, chunksize=1000, index_col=0, na_filter=False):
        if len(cells) == 0:
            cells = chunk.columns
            areas = [0] * chunk.columns.size
        
        genes.extend(list(chunk.index))
        sparseblock = sparse.csr_matrix(chunk.values.astype(float))
        sparseblocks.append(sparseblock)
        print('.', end='', flush=True)

    print(' done')
    counts = sparse.vstack(sparseblocks, format='csr')
    return counts.T, np.array(genes), cells, np.array(areas)

filename = 'mouse_VISp_2018-06-14_exon-matrix.csv'
counts, genes, cells, areas = sparseload(filename)
# Out:
# .............................................. done

# %%
print(counts.shape)
# Out:
# (15413, 45768)

# %%
print(genes)
# Out:
# [    71661     76253     58520 ... 100861498 100861500 100861503]

# %%
print(genes.shape)
# Out:
# (45768,)

# %%
print(cells)
# Out:
# Index(['F1S4_160108_001_A01', 'F1S4_160108_001_B01', 'F1S4_160108_001_C01',
#        'F1S4_160108_001_D01', 'F1S4_160108_001_E01', 'F1S4_160108_001_F01',
#        'F1S4_160108_001_G01', 'F1S4_160108_001_H01', 'F1S4_160108_002_A01',
#        'F1S4_160108_002_B01',
#        ...
#        'FYS4_171004_103_G01', 'FYS4_171004_103_H01', 'FYS4_171004_104_A01',
#        'FYS4_171004_104_B01', 'FYS4_171004_104_C01', 'FYS4_171004_104_D01',
#        'FYS4_171004_104_E01', 'FYS4_171004_104_F01', 'FYS4_171004_104_G01',
#        'FYS4_171004_104_H01'],
#       dtype='object', length=15413)

# %%
print(cells.shape)
# Out:
# (15413,)

# %%
genesdf= pd.read_csv('mouse_VISp_2018-06-14_genes-rows.csv')
gene_ids= genesdf['gene_entrez_id'].tolist()
symbols = genesdf['gene_symbol'].tolist()
id2symbol = dict(zip(gene_ids, symbols))
genes = np.array([id2symbol[i] for i in gene_ids])

clusterInfo = pd.read_csv('sample_heatmap_plot_data.csv')
goodCells  = clusterInfo['sample_name'].values
cluster_ids = clusterInfo['cluster_id'].values
labels     = clusterInfo['cluster_label'].values
colors     = clusterInfo['cluster_color'].values
print('goodCells:',goodCells.shape)
print('cluster_ids:',cluster_ids.shape)
print('labels:',labels.shape)
print('colors:',colors.shape)
# Out:
# goodCells: (23822,)
# cluster_ids: (23822,)
# labels: (23822,)
# colors: (23822,)

# %%
print(cluster_ids)
# Out:
# [94 73  2 ... 89 35 57]

# %%
print(clusters)
# Out:
# [93 72  1 ... 88 34 56]

# %%
cellsf=cells

# %%
good_cells_order_idx = []
cluster_ids_new = []

for c in goodCells:
    indices = np.where(cellsf == c)[0]  # Assuming cells is the correct array to search in
    if len(indices) > 0:
        good_cells_order_idx.append(indices[0])
        cluster_ids_new.append(cluster_ids[indices[0]])
    else:
        print(f"Cluster '{c}' not found in cells.")

print("Indices of clusters found in both goodCells and cells:")
print(good_cells_order_idx)
print("Cluster IDs corresponding to the indices:")
print(cluster_ids_new.shape)
# Out:
# Cluster 'F1S4_161216_001_A01' not found in cells.
# Cluster 'F1S4_180124_314_A01' not found in cells.
# Cluster 'F1S4_180124_315_A01' not found in cells.
# Cluster 'F1S4_180124_315_B01' not found in cells.
# Cluster 'F1S4_180124_315_C01' not found in cells.
# Cluster 'F1S4_180124_315_D01' not found in cells.
# Cluster 'F1S4_180124_315_E01' not found in cells.
# Cluster 'F1S4_180124_315_F01' not found in cells.
# Cluster 'F1S4_180124_315_G01' not found in cells.
# Cluster 'F1S4_180124_315_H01' not found in cells.
# Cluster 'F1S4_180124_316_A01' not found in cells.
# Cluster 'F1S4_180124_316_B01' not found in cells.
# Cluster 'F1S4_180124_316_C01' not found in cells.
# Cluster 'F1S4_180124_316_D01' not found in cells.
# Cluster 'F1S4_180124_316_E01' not found in cells.
# Cluster 'F1S4_180124_316_F01' not found in cells.
# Cluster 'F1S4_180124_316_G01' not found in cells.
# Cluster 'F1S4_180124_316_H01' not found in cells.
# Cluster 'F1S4_180124_317_A01' not found in cells.
# ...

# %%
clusters   = np.copy(cluster_ids_new) - 1

# %%
clusters.shape
# Out:
# (14249,)

# %%
good_cells_order_idx = np.array(good_cells_order_idx)

# Reorder counts and cells
counts = counts[good_cells_order_idx,:]
cellsf = cellsf[good_cells_order_idx]

# %%
print(counts)
# Out:
#   (42, 0)	24.0
#   (340, 0)	2.0
#   (441, 0)	14.0
#   (451, 0)	16.0
#   (484, 0)	5.0
#   (555, 0)	29.0
#   (595, 0)	3.0
#   (689, 0)	2.0
#   (731, 0)	1.0
#   (823, 0)	4.0
#   (833, 0)	1.0
#   (863, 0)	7.0
#   (895, 0)	9.0
#   (898, 0)	22.0
#   (944, 0)	36.0
#   (946, 0)	1.0
#   (985, 0)	1.0
#   (1068, 0)	12.0
#   (1069, 0)	1.0
#   (1158, 0)	12.0
#   (1160, 0)	1.0
#   (1215, 0)	7.0
#   (1247, 0)	5.0
#   (1275, 0)	1.0
#   (1276, 0)	5.0
#   :	:
#   (1842, 45759)	1.0
#   (1901, 45759)	1.0
#   (2356, 45759)	1.0
#   (2753, 45759)	2.0
#   (2928, 45759)	2.0
#   (3214, 45759)	1.0
#   (3454, 45759)	1.0
#   (4076, 45759)	1.0
#   (5586, 45759)	1.0
#   (6039, 45759)	3.0
#   (6208, 45759)	2.0
#   (6331, 45759)	2.0
#   (6626, 45759)	1.0
#   (8220, 45759)	1.0
#   (8224, 45759)	1.0
#   (8541, 45759)	1.0
#   (10293, 45759)	1.0
#   (10499, 45759)	1.0
#   (10796, 45759)	1.0
#   (11232, 45759)	1.0
#   (12126, 45759)	1.0
#   (12242, 45759)	1.0
#   (12358, 45759)	1.0
#   (12971, 45759)	2.0
# ...

# %%
print(counts.shape)
# Out:
# (14249, 45768)

# %%
print(clusters.shape)
# Out:
# (14249,)

# %%
print(cellsf.shape)
# Out:
# (14249,)

# %%
adata = anndata.AnnData(X=counts,
                        obs=dict(clusters=clusters,
                                 cellsf=np.array(cellsf)),
                        var=dict(genes=genes))

# %%
print('counts shape:', counts.T.shape)
print('cells shape:', cellsf.shape)

# Check lengths
print('Length of cells:', len(cellsf))
# Out:
# counts shape: (15413, 14249)
# cells shape: (14249,)
# Length of cells: 14249
